# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <span style="color:black;font-size: 30px; font-family: Arial; font-weight: bold;"> EDUNET FOUNDATION-Self Paced Solution Notebook</span>

# %% [markdown]
# <span style="color:black;font-size: 30px; font-family: Arial; font-weight: bold;"> Lab-2 Playing with plots using matplotlib, graphs most preferable by Data Analyst</span>

# %% [markdown]
# <span style="color:black;font-size: 25px; font-family: Arial; font-weight: bold;"> Exercise  </span>

# %% [markdown]
# <span style="color:black;font-size: 25px; font-family: Arial; font-weight: bold;"> Program 1 - Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively. </span>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# plt.show() for non-notebook users

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %%
fig = plt.figure()

ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,.2,.2])

# %% [markdown]
# <span style="color:black;font-size: 25px; font-family: Arial; font-weight: bold;"> Program 2 - Now plot (x,y) on both axes. And call your figure object to show it. </span>

# %%
ax1.plot(x,y)
ax1.set_xlabel('x')
ax1.set_ylabel('y')


ax2.plot(x,y)
ax2.set_xlabel('x')
ax2.set_ylabel('y')

fig # Show figure object

# %% [markdown]
# <span style="color:black;font-size: 25px; font-family: Arial; font-weight: bold;"> Program 3 - Now create a boxplot each in horizontal and vertical direction </span>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)

# fake up some data
spread = np.random.rand(50) * 100
center = np.ones(25) * 50
flier_high = np.random.rand(10) * 100 + 100
flier_low = np.random.rand(10) * -100
data = np.concatenate((spread, center, flier_high, flier_low))

# %%
# Vertical Boxplot
green_diamond = dict(markerfacecolor='orange', marker='D')
fig3, ax3 = plt.subplots()
ax3.set_title('Vertical Boxplot')
ax3.boxplot(data, flierprops=green_diamond)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2041de180a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2041de18760>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2041de0bd00>],
#  'medians': [<matplotlib.lines.Line2D at 0x2041de18e20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2041de241c0>],
#  'means': []}

# %%
# Horizontal Boxplot
green_diamond = dict(markerfacecolor='orange', marker='D')
fig3, ax3 = plt.subplots()
ax3.set_title('Horizontal Boxplot')
ax3.boxplot(data, vert = False,flierprops=green_diamond)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2041de7c0d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2041de7c790>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2041de70d30>],
#  'medians': [<matplotlib.lines.Line2D at 0x2041de7ce50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2041de8a1f0>],
#  'means': []}

# %% [markdown]
# <span style="color:black;font-size: 25px; font-family: Arial; font-weight: bold;"> Program 4 - Now create a lineplot and add Ticks , Legends , LabeL , Grid,Text and Annotation in Graph </span>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Y-axis values
y1 = [2, 3, 4.5]

# Y-axis values
y2 = [1, 1.5, 5]

# Function to add label and ticks
plt.tick_params (axis="x", labelsize=18, labelrotation=-60, labelcolor="turquoise") 
plt.tick_params (axis="y", labelsize=12, labelrotation=20, labelcolor="orange")



# Function add a Grid
plt.grid(True)

# Function to plot
plt.plot(y1)
plt.plot(y2)

# Function add a legend
plt.legend(["blue", "green"], loc ="lower right")

# function to show the plot
plt.show()
