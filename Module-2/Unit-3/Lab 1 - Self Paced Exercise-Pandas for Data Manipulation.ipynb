# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <span style="color:black;font-size: 30px; font-family: Arial; font-weight: bold;"> EDUNET FOUNDATION-Self Paced Exercise Notebook</span>

# %% [markdown]
# <span style="color:black;font-size: 30px; font-family: Arial; font-weight: bold;"> Lab 1 - Pandas for Data Manipulation </span>

# %% [markdown]
# <span style="color:black;font-size: 20px; font-family: Arial; font-weight: bold;"> Problem 1: Creating a Series:  </span>

# %% [markdown]
# <span style="color:black;font-size: 20px; font-family: Arial; font-weight: bold;"> a) - Create a Pandas Series containing the days of the week: Monday, Tuesday, ..., Sunday. </span>

# %% [markdown]
# <span style="color:black;font-size: 20px; font-family: Arial; font-weight: bold;"> b) - Set custom indices for the Series to represent numbers 1 to 7. </span>

# %% [markdown]
# <span style="color:black;font-size: 20px; font-family: Arial; font-weight: bold;"> c) - Print the day of the week corresponding to index 4. </span>

# %% [markdown]
# <span style="color:black;font-size: 20px; font-family: Arial; font-weight: bold;"> Problem 2 : Create a DataFrame with the following data:
# </span>

# %% [markdown]
# Columns: 'Name', 'Age', 'City'

# %% [markdown]
# Rows: ['Alice', 25, 'New York'], ['Bob', 30, 'Los Angeles'], ['Charlie', 28, 'Chicago']

# %% [markdown]
# <span style="color:black;font-size: 25px; font-family: Arial; font-weight: bold;"> Problem 3: By using above data frame,  answer the following Questions: <br> a) - Print the 'Name' column of the DataFrame.<br> b) - Sort the DataFrame by 'Age' in ascending order.<br> c) - Print the shape of the dataframe.
# </span>

# %% [markdown]
# <span style="color:black;font-size: 25px; font-family: Arial; font-weight: bold;"> Problem 4: We have the following DataFrame with two columns and ten rows. We want to fill the missing values in the measurement column with their previous values, but we’re only allowed to fill two consecutive values with this method. The remaining ones need to be filled with the average value of the column.</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <span style="color:black;font-size: 25px; font-family: Arial; font-weight: bold;"> Problem 5: Suppose you are working as music analyst in XYZ company. Your Manager provide you a dataset and by using the dataset you have to answer following Questions: <br> a) - FInd the total number of plays for each country?<br> b) - Find the total number of plays per each country/genre combination?<br> c) - Print all records where genre is rock?</span>

# %%
import pandas as pd
music_df=pd.read_csv("music.csv")
music_df
# Out:
#               artist  country  plays  genre  fans
# 0        The Beatles       UK    150   rock    50
# 1         Pink Floyd       UK  10000   rock  1500
# 2          Metallica       US    500  metal    50
# 3           Cairokee    Egypt    200   rock    10
# 4               ACDC       US    250   rock    20
# 5          The Doors       US   1000   rock    80
# 6  Poets of The Fall  Finland    250   rock    10
# 7           Megadeth       US    300  metal    20
# 8        Iron Maiden       UK  20000  metal  3500
# 9       Judas Priest       UK   5000  metal  1000
